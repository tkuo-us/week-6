# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---
#
# # Exercises
#
# For these exercises, you'll be creating a [Python class](https://www.hackerearth.com/practice/python/object-oriented-programming/classes-and-objects-i/tutorial/) in the *apputil.py* file.
#
# A few tips:
#
# - Some of these exercises will require some "JSON digging".
# - <font color='lightblue'>Your functions should still adhere to [best practices](https://codesignal.com/learn/courses/clean-code-basics-with-python/lessons/clean-function-design-in-python), so **your class should probably contain more functions than only the ones dictated below**.</font>

# %% [markdown]
# ## Exercise 1
#
# Create a Python class named `Genius` such that the following code initializes the object, and "saves" the access token as an attribute of the object. You'll need to use this attribute for Exercises 2 and 3.
#
# ```python
# from apputil import Genius
#
# genius = Genius(access_token="access_token")
# ```

# %%
from apputil import Genius
genius = Genius(access_token="xD6CLTcujl3da5Lw0FqobrkAQBjLjJ1Gpa2mtOXP5j0LlzfxFNlSATT5ZD4L09NP")

# %% [markdown]
# ## Exercise 2
#
# Reference the `json_data` in the lab. Notice, when we search for an artist name (e.g., "Missy Elliot") in Genius, the result is a list of *songs* attributed to that artist. Suppose we want to capture information about the artist themselves.
#
# Create a method for our `Genius` class called `.get_artist(search_term)` which does the following:
#
# 1. Extract the (most likely, "Primary") Artist ID from the first "hit" of the `search_term`.
# 2. Use the [API path](https://docs.genius.com/#artists-h2) for this Artist ID to pull information about the artist.
# 3. **Return** the dictionary containing the resulting JSON object.
#
# For example, the following code should return a dictionary of artist information:
#
# ```python
# genius.get_artist("Radiohead")
# ```

# %%
# Ex2
artist = genius.get_artist("Radiohead")
artist
# Out:
# {'alternate_names': [],
#  'api_path': '/artists/604',
#  'description': {'dom': {'tag': 'root',
#    'children': [{'tag': 'p',
#      'children': [{'tag': 'a',
#        'attributes': {'href': 'https://www.radiohead.com/',
#         'rel': 'noopener nofollow'},
#        'children': ['Radiohead']},
#       ' emerged from the shadow of ‘90s Brit-pop with a sound that was moody, melodic, and explosive; with roots planted firmly in both alternative culture and the art-rock legacy of groups like ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Pink-floyd',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/694'},
#        'children': ['Pink Floyd']},
#       ', ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Rem',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/8243'},
#        'children': ['R.E.M.']},
#       ', ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/The-smiths',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/16669'},
#        'children': ['The Smiths']},
#       ', and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Talking-heads',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/13347'},
#        'children': ['Talking Heads']},
#       '—from whose ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/Talking-heads-radio-head-lyrics',
#         'rel': 'noopener'},
#        'data': {'api_path': '/songs/691833'},
#        'children': ['song']},
#       ' they derived their name.']},
#     '',
#     {'tag': 'p',
#      'children': ['They formed in 1985, as ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/On-a-friday',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/231288'},
#        'children': ['On A Friday']},
#       ', named after the day they’d usually rehearse. The line-up hasn’t changed since: ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Thom-yorke',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/49096'},
#        'children': ['Thom Yorke']},
#       ' (guitar/vocals), ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Ed-obrien',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/664806'},
#        'children': ["Ed O'Brien"]},
#       ' (guitar), ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Philip-selway',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/240814'},
#        'children': ['Philip Selway']},
#       ' (drums) and brothers ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Colin-greenwood',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/664805'},
#        'children': ['Colin']},
#       ' and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Jonny-greenwood',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/287476'},
#        'children': ['Jonny Greenwood']},
#       ' on bass and lead guitar, respectively.']},
#     '',
#     {'tag': 'p',
#      'children': ['In 1991, they signed with ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Emi-group-limited',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/1681459'},
#        'children': ['EMI']},
#       ', changed their name to Radiohead, and recorded their first EP, ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Drill-ep',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/152652'},
#        'children': [{'tag': 'em', 'children': ['Drill']}]},
#       '. They released the record in 1992 to little impact, debuting on the ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.theguardian.com/music/gallery/2007/oct/09/radiohead',
#         'rel': 'noopener nofollow'},
#        'children': ['UK Charts at #101']},
#       '. It wasn’t until their catchy 1992 single ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/Radiohead-creep-lyrics',
#         'rel': 'noopener'},
#        'data': {'api_path': '/songs/109096'},
#        'children': ['“Creep”']},
#       ' became a massive hit that the band was launched into the limelight.']},
#     '',
#     {'tag': 'p',
#      'children': ['When the band released ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Pablo-honey',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/21232'},
#        'children': [{'tag': 'em', 'children': ['Pablo Honey']}]},
#       ' in 1993, however, most critics believed they would be a one-hit wonder—an opinion they proved wrong with 1995’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/The-bends',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/16306'},
#        'children': [{'tag': 'em', 'children': ['The Bends']}]},
#       '; a much more complex and mature sophomore effort. With the release of 1997’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Ok-computer',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/17915'},
#        'children': [{'tag': 'em', 'children': ['OK Computer']}]},
#       ', their newfound status was solidified. It was widely considered to be the best record of the year and listed among the most important rock albums of the 1990s. Radiohead became one of the most closely watched and influential bands of that decade.']},
#     '',
#     {'tag': 'p',
#      'children': ['Their response to the hype was two experimental follow-ups: October 2000’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Kid-a',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/10781'},
#        'children': [{'tag': 'em', 'children': ['Kid A']}]},
#       ' and May 2001’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Amnesiac',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/17548'},
#        'children': [{'tag': 'em', 'children': ['Amnesiac']}]},
#       '. Venturing into less radio-friendly territory, Radiohead was now far from their Brit-pop beginnings, taking more influence from avant-garde composers such as ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Krzysztof-penderecki',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/1127117'},
#        'children': ['Krzysztof Penderecki']},
#       ', ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Olivier-messiaen',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/1167488'},
#        'children': ['Olivier Messiaen']},
#       ', and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Scott-walker',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/53293'},
#        'children': ['Scott Walker']},
#       '. Their lyrics also became more politicized.']},
#     '',
#     {'tag': 'p',
#      'children': ['In June 2003, they released their sixth album, ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/Hail-to-the-thief',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/19640'},
#        'children': [{'tag': 'em', 'children': ['Hail to the Thief']}]},
#       ', lyrically influenced by “the general sense of ignorance and intolerance and panic and stupidity” as Thom Yorke ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://eagleviewnews.com/2016/04/12/radiohead/',
#         'rel': 'noopener nofollow'},
#        'children': ['suggested']},
#       '. It was also regarded as Radiohead’s most ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#         'rel': 'noopener nofollow'},
#        'children': ['political']},
#       ' act to date, fueled with anger and objection, because of the themes based on the ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#         'rel': 'noopener nofollow'},
#        'children': ['US election']},
#       ' and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#         'rel': 'noopener nofollow'},
#        'children': ['George W. Bush candidacy']},
#       '.']},
#     '',
#     {'tag': 'p',
#      'children': ['During the recording of their next album, October 2007’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/In-rainbows',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/14959'},
#        'children': [{'tag': 'em', 'children': ['In Rainbows']}]},
#       ', Radiohead was ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.nytimes.com/2006/07/02/arts/music/02pare.html',
#         'rel': 'noopener nofollow'},
#        'children': ['considered']},
#       ' to be the most popular unsigned band in the world, since parting ways with EMI. However, they made a bold decision to ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.telegraph.co.uk/finance/markets/2816893/Radiohead-challenges-labels-with-free-album.html',
#         'rel': 'noopener nofollow'},
#        'children': ['publish']},
#       ' their album online, independently and without the help of a major label, using a “pay what you want” system, allowing listeners to pay for the album at whatever price they felt like paying; including for free. Regardless, the album ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.theguardian.com/music/2008/oct/16/radiohead-album-sales',
#         'rel': 'noopener nofollow'},
#        'children': ['sold']},
#       ' more copies than their previous albums. ',
#       {'tag': 'em', 'children': ['In Rainbows']},
#       ' peaked at #1 on both the US and UK ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.billboard.com/music/radiohead/chart-history/top-album-sales',
#         'rel': 'noopener nofollow'},
#        'children': [{'tag': 'em', 'children': ['Billboard']}, ' charts']},
#       ', won ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.grammy.com/grammys/artists/radiohead',
#         'rel': 'noopener nofollow'},
#        'children': ['two Grammy Awards']},
#       ', and was placed among ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.rollingstone.com/music/music-lists/500-greatest-albums-of-all-time-156826/radiohead-in-rainbows-38107/',
#         'rel': 'noopener nofollow'},
#        'children': ['Rolling Stone’s top 500 albums of all time']},
#       '.']},
#     '',
#     {'tag': 'p',
#      'children': ['After four years of absence, Radiohead returned in Feburary 2011 with a new album, ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/The-king-of-limbs',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/36451'},
#        'children': [{'tag': 'em', 'children': ['The King of the Limbs']}]},
#       '. This project was ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.stereogum.com/1786306/in-defense-of-the-king-of-limbs/franchises/sounding-board/',
#         'rel': 'noopener nofollow'},
#        'children': ['not as acclaimed']},
#       ' by fans and critics as their previous works were. ',
#       {'tag': 'em', 'children': ['King of Limbs']},
#       ' was their shortest album to date, but saw natural evolutions of previously explored directions; The album was considered to be an interaction between technology and the natural world.']},
#     '',
#     {'tag': 'p',
#      'children': ['May 2016’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/A-moon-shaped-pool',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/151702'},
#        'children': [{'tag': 'em', 'children': ['A Moon Shaped Pool']}]},
#       ' found Radiohead taking a more personal journey and moving beyond their existential dreads. ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://pitchfork.com/reviews/albums/21907-a-moon-shaped-pool/',
#         'rel': 'noopener nofollow'},
#        'children': [{'tag': 'em', 'children': ['Pitchfork']}]},
#       ' gave the album a 9.1 out of 10.']},
#     '',
#     {'tag': 'p',
#      'children': ['Up to 2019, Radiohead has released nine studio albums, always experimenting with new sounds as well as alternative marketing strategies—especially since ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.nytimes.com/2007/10/23/business/media/23music.html',
#         'rel': 'noopener nofollow'},
#        'children': ['going independent']},
#       ' with the release of their acclaimed 2007 album ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Radiohead/In-rainbows',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/14959'},
#        'children': [{'tag': 'em', 'children': ['In Rainbows']}]},
#       '.']},
#     '',
#     {'tag': 'p',
#      'children': ['Since the mid-2000s, band members have also worked on side projects, with the bands ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/Atoms-for-peace',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/24846'},
#        'children': ['Atoms for Peace']},
#       ' and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/artists/7-worlds-collide',
#         'rel': 'noopener'},
#        'data': {'api_path': '/artists/1525999'},
#        'children': ['7 Worlds Collide']},
#       '. Thom Yorke began working on solo records, starting with 2006’s ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Thom-yorke/The-eraser',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/33215'},
#        'children': [{'tag': 'em', 'children': ['The Eraser']}]},
#       ', moving forward to publish ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Thom-yorke/Tomorrows-modern-boxes',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/113654'},
#        'children': [{'tag': 'em', 'children': ['Tomorrow’s Modern Boxes']}]},
#       ' in September 2014 and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Thom-yorke/Anima',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/495112'},
#        'children': [{'tag': 'em', 'children': ['ANIMA']}]},
#       ' in June 2019. Additionally, Jonny Greenwood collaborated with ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://www.stereogum.com/1983217/jonny-greenwood-and-paul-thomas-anderson-seem-to-have-a-delightful-working-relationship/news/',
#         'rel': 'noopener nofollow'},
#        'children': ['Paul Thomas Anderson']},
#       ' to compose soundtracks for the movies ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/There-will-be-blood-original-motion-picture-soundtrack',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/389119'},
#        'children': [{'tag': 'em', 'children': ['There Will Be Blood']}]},
#       ' (2007), ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/The-master-original-motion-picture-soundtrack',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/341700'},
#        'children': [{'tag': 'em', 'children': ['The Master']}]},
#       ' (2012), and ',
#       {'tag': 'a',
#        'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/Phantom-thread-original-motion-picture-soundtrack',
#         'rel': 'noopener'},
#        'data': {'api_path': '/albums/389126'},
#        'children': [{'tag': 'em', 'children': ['Phantom Thread']}]},
#       ' (2017).']}]}},
#  'facebook_name': 'radiohead',
#  'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#  'id': 604,
#  'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#  'instagram_name': 'radiohead',
#  'is_meme_verified': False,
#  'is_verified': False,
#  'name': 'Radiohead',
#  'translation_artist': False,
#  'twitter_name': 'radiohead',
#  'url': 'https://genius.com/artists/Radiohead',
#  'current_user_metadata': {'permissions': ['follow',
#    'view_activity_stream',
#    'view_contribution_opportunities',
#    'view_discography'],
#   'excluded_permissions': ['edit',
#    'edit_images',
#    'edit_names',
#    'edit_anything',
#    'merge',
#    'sort_artist_songs',
#    'edit_translation_artist',
#    'split',
#    'see_short_id'],
#   'interactions': {'following': False}},
#  'followers_count': 2554,
#  'description_annotation': {'_type': 'referent',
#   'annotator_id': 7,
#   'annotator_login': 'Maboo',
#   'api_path': '/referents/6926495',
#   'classification': 'accepted',
#   'fragment': 'Radiohead',
#   'id': 6926495,
#   'is_description': True,
#   'path': '/6926495/Radiohead/Radiohead',
#   'range': {'content': 'Radiohead'},
#   'song_id': None,
#   'url': 'https://genius.com/6926495/Radiohead/Radiohead',
#   'verified_annotator_ids': [],
#   'annotatable': {'api_path': '/artists/604',
#    'context': None,
#    'id': 604,
#    'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#    'link_title': 'Radiohead',
#    'title': 'Radiohead',
#    'type': 'Artist',
#    'url': 'https://genius.com/artists/Radiohead'},
#   'annotations': [{'api_path': '/annotations/6926495',
#     'body': {'dom': {'tag': 'root',
#       'children': [{'tag': 'p',
#         'children': [{'tag': 'a',
#           'attributes': {'href': 'https://www.radiohead.com/',
#            'rel': 'noopener nofollow'},
#           'children': ['Radiohead']},
#          ' emerged from the shadow of ‘90s Brit-pop with a sound that was moody, melodic, and explosive; with roots planted firmly in both alternative culture and the art-rock legacy of groups like ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Pink-floyd',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/694'},
#           'children': ['Pink Floyd']},
#          ', ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Rem',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/8243'},
#           'children': ['R.E.M.']},
#          ', ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/The-smiths',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/16669'},
#           'children': ['The Smiths']},
#          ', and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Talking-heads',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/13347'},
#           'children': ['Talking Heads']},
#          '—from whose ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/Talking-heads-radio-head-lyrics',
#            'rel': 'noopener'},
#           'data': {'api_path': '/songs/691833'},
#           'children': ['song']},
#          ' they derived their name.']},
#        '',
#        {'tag': 'p',
#         'children': ['They formed in 1985, as ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/On-a-friday',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/231288'},
#           'children': ['On A Friday']},
#          ', named after the day they’d usually rehearse. The line-up hasn’t changed since: ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Thom-yorke',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/49096'},
#           'children': ['Thom Yorke']},
#          ' (guitar/vocals), ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Ed-obrien',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/664806'},
#           'children': ["Ed O'Brien"]},
#          ' (guitar), ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Philip-selway',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/240814'},
#           'children': ['Philip Selway']},
#          ' (drums) and brothers ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Colin-greenwood',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/664805'},
#           'children': ['Colin']},
#          ' and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Jonny-greenwood',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/287476'},
#           'children': ['Jonny Greenwood']},
#          ' on bass and lead guitar, respectively.']},
#        '',
#        {'tag': 'p',
#         'children': ['In 1991, they signed with ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Emi-group-limited',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/1681459'},
#           'children': ['EMI']},
#          ', changed their name to Radiohead, and recorded their first EP, ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Drill-ep',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/152652'},
#           'children': [{'tag': 'em', 'children': ['Drill']}]},
#          '. They released the record in 1992 to little impact, debuting on the ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.theguardian.com/music/gallery/2007/oct/09/radiohead',
#            'rel': 'noopener nofollow'},
#           'children': ['UK Charts at #101']},
#          '. It wasn’t until their catchy 1992 single ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/Radiohead-creep-lyrics',
#            'rel': 'noopener'},
#           'data': {'api_path': '/songs/109096'},
#           'children': ['“Creep”']},
#          ' became a massive hit that the band was launched into the limelight.']},
#        '',
#        {'tag': 'p',
#         'children': ['When the band released ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Pablo-honey',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/21232'},
#           'children': [{'tag': 'em', 'children': ['Pablo Honey']}]},
#          ' in 1993, however, most critics believed they would be a one-hit wonder—an opinion they proved wrong with 1995’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/The-bends',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/16306'},
#           'children': [{'tag': 'em', 'children': ['The Bends']}]},
#          '; a much more complex and mature sophomore effort. With the release of 1997’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Ok-computer',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/17915'},
#           'children': [{'tag': 'em', 'children': ['OK Computer']}]},
#          ', their newfound status was solidified. It was widely considered to be the best record of the year and listed among the most important rock albums of the 1990s. Radiohead became one of the most closely watched and influential bands of that decade.']},
#        '',
#        {'tag': 'p',
#         'children': ['Their response to the hype was two experimental follow-ups: October 2000’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Kid-a',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/10781'},
#           'children': [{'tag': 'em', 'children': ['Kid A']}]},
#          ' and May 2001’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Amnesiac',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/17548'},
#           'children': [{'tag': 'em', 'children': ['Amnesiac']}]},
#          '. Venturing into less radio-friendly territory, Radiohead was now far from their Brit-pop beginnings, taking more influence from avant-garde composers such as ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Krzysztof-penderecki',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/1127117'},
#           'children': ['Krzysztof Penderecki']},
#          ', ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Olivier-messiaen',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/1167488'},
#           'children': ['Olivier Messiaen']},
#          ', and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Scott-walker',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/53293'},
#           'children': ['Scott Walker']},
#          '. Their lyrics also became more politicized.']},
#        '',
#        {'tag': 'p',
#         'children': ['In June 2003, they released their sixth album, ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/Hail-to-the-thief',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/19640'},
#           'children': [{'tag': 'em', 'children': ['Hail to the Thief']}]},
#          ', lyrically influenced by “the general sense of ignorance and intolerance and panic and stupidity” as Thom Yorke ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://eagleviewnews.com/2016/04/12/radiohead/',
#            'rel': 'noopener nofollow'},
#           'children': ['suggested']},
#          '. It was also regarded as Radiohead’s most ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#            'rel': 'noopener nofollow'},
#           'children': ['political']},
#          ' act to date, fueled with anger and objection, because of the themes based on the ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#            'rel': 'noopener nofollow'},
#           'children': ['US election']},
#          ' and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.rollingstone.com/music/music-news/bitter-prophet-thom-yorke-on-hail-to-the-thief-87869/',
#            'rel': 'noopener nofollow'},
#           'children': ['George W. Bush candidacy']},
#          '.']},
#        '',
#        {'tag': 'p',
#         'children': ['During the recording of their next album, October 2007’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/In-rainbows',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/14959'},
#           'children': [{'tag': 'em', 'children': ['In Rainbows']}]},
#          ', Radiohead was ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.nytimes.com/2006/07/02/arts/music/02pare.html',
#            'rel': 'noopener nofollow'},
#           'children': ['considered']},
#          ' to be the most popular unsigned band in the world, since parting ways with EMI. However, they made a bold decision to ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.telegraph.co.uk/finance/markets/2816893/Radiohead-challenges-labels-with-free-album.html',
#            'rel': 'noopener nofollow'},
#           'children': ['publish']},
#          ' their album online, independently and without the help of a major label, using a “pay what you want” system, allowing listeners to pay for the album at whatever price they felt like paying; including for free. Regardless, the album ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.theguardian.com/music/2008/oct/16/radiohead-album-sales',
#            'rel': 'noopener nofollow'},
#           'children': ['sold']},
#          ' more copies than their previous albums. ',
#          {'tag': 'em', 'children': ['In Rainbows']},
#          ' peaked at #1 on both the US and UK ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.billboard.com/music/radiohead/chart-history/top-album-sales',
#            'rel': 'noopener nofollow'},
#           'children': [{'tag': 'em', 'children': ['Billboard']}, ' charts']},
#          ', won ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.grammy.com/grammys/artists/radiohead',
#            'rel': 'noopener nofollow'},
#           'children': ['two Grammy Awards']},
#          ', and was placed among ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.rollingstone.com/music/music-lists/500-greatest-albums-of-all-time-156826/radiohead-in-rainbows-38107/',
#            'rel': 'noopener nofollow'},
#           'children': ['Rolling Stone’s top 500 albums of all time']},
#          '.']},
#        '',
#        {'tag': 'p',
#         'children': ['After four years of absence, Radiohead returned in Feburary 2011 with a new album, ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/The-king-of-limbs',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/36451'},
#           'children': [{'tag': 'em', 'children': ['The King of the Limbs']}]},
#          '. This project was ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.stereogum.com/1786306/in-defense-of-the-king-of-limbs/franchises/sounding-board/',
#            'rel': 'noopener nofollow'},
#           'children': ['not as acclaimed']},
#          ' by fans and critics as their previous works were. ',
#          {'tag': 'em', 'children': ['King of Limbs']},
#          ' was their shortest album to date, but saw natural evolutions of previously explored directions; The album was considered to be an interaction between technology and the natural world.']},
#        '',
#        {'tag': 'p',
#         'children': ['May 2016’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/A-moon-shaped-pool',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/151702'},
#           'children': [{'tag': 'em', 'children': ['A Moon Shaped Pool']}]},
#          ' found Radiohead taking a more personal journey and moving beyond their existential dreads. ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://pitchfork.com/reviews/albums/21907-a-moon-shaped-pool/',
#            'rel': 'noopener nofollow'},
#           'children': [{'tag': 'em', 'children': ['Pitchfork']}]},
#          ' gave the album a 9.1 out of 10.']},
#        '',
#        {'tag': 'p',
#         'children': ['Up to 2019, Radiohead has released nine studio albums, always experimenting with new sounds as well as alternative marketing strategies—especially since ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.nytimes.com/2007/10/23/business/media/23music.html',
#            'rel': 'noopener nofollow'},
#           'children': ['going independent']},
#          ' with the release of their acclaimed 2007 album ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Radiohead/In-rainbows',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/14959'},
#           'children': [{'tag': 'em', 'children': ['In Rainbows']}]},
#          '.']},
#        '',
#        {'tag': 'p',
#         'children': ['Since the mid-2000s, band members have also worked on side projects, with the bands ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/Atoms-for-peace',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/24846'},
#           'children': ['Atoms for Peace']},
#          ' and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/artists/7-worlds-collide',
#            'rel': 'noopener'},
#           'data': {'api_path': '/artists/1525999'},
#           'children': ['7 Worlds Collide']},
#          '. Thom Yorke began working on solo records, starting with 2006’s ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Thom-yorke/The-eraser',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/33215'},
#           'children': [{'tag': 'em', 'children': ['The Eraser']}]},
#          ', moving forward to publish ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Thom-yorke/Tomorrows-modern-boxes',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/113654'},
#           'children': [{'tag': 'em',
#             'children': ['Tomorrow’s Modern Boxes']}]},
#          ' in September 2014 and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Thom-yorke/Anima',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/495112'},
#           'children': [{'tag': 'em', 'children': ['ANIMA']}]},
#          ' in June 2019. Additionally, Jonny Greenwood collaborated with ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://www.stereogum.com/1983217/jonny-greenwood-and-paul-thomas-anderson-seem-to-have-a-delightful-working-relationship/news/',
#            'rel': 'noopener nofollow'},
#           'children': ['Paul Thomas Anderson']},
#          ' to compose soundtracks for the movies ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/There-will-be-blood-original-motion-picture-soundtrack',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/389119'},
#           'children': [{'tag': 'em', 'children': ['There Will Be Blood']}]},
#          ' (2007), ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/The-master-original-motion-picture-soundtrack',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/341700'},
#           'children': [{'tag': 'em', 'children': ['The Master']}]},
#          ' (2012), and ',
#          {'tag': 'a',
#           'attributes': {'href': 'https://genius.com/albums/Jonny-greenwood/Phantom-thread-original-motion-picture-soundtrack',
#            'rel': 'noopener'},
#           'data': {'api_path': '/albums/389126'},
#           'children': [{'tag': 'em', 'children': ['Phantom Thread']}]},
#          ' (2017).']}]}},
#     'comment_count': 1,
#     'community': True,
#     'custom_preview': None,
#     'has_voters': True,
#     'id': 6926495,
#     'pinned': False,
#     'share_url': 'https://genius.com/6926495',
#     'source': None,
#     'state': 'accepted',
#     'url': 'https://genius.com/6926495/Radiohead/Radiohead',
#     'verified': False,
#     'votes_total': 302,
#     'current_user_metadata': {'permissions': ['vote',
#       'propose_edit_to',
#       'report_as_abusive',
#       'create_comment'],
#      'excluded_permissions': ['edit',
#       'cosign',
#       'uncosign',
#       'destroy',
#       'accept',
#       'reject',
#       'see_unreviewed',
#       'clear_votes',
#       'pin_to_profile',
#       'unpin_from_profile',
#       'update_source',
#       'edit_custom_preview'],
#      'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#      'iq_by_action': {'accept': {'primary': {'multiplier': 1,
#         'base': 10.0,
#         'applicable': True}},
#       'reject': {'primary': {'multiplier': 1,
#         'base': 2.0,
#         'applicable': True}},
#       'delete': {'primary': {'multiplier': 1,
#         'base': 5.0,
#         'applicable': True}}}},
#     'authors': [{'attribution': 0.36447166921898927,
#       'pinned_role': None,
#       'user': {'api_path': '/users/1435772',
#        'avatar': {'tiny': {'url': 'https://filepicker-images.genius.com/lal7cj4tzmq',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://filepicker-images.genius.com/lal7cj4tzmq',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://filepicker-images.genius.com/lal7cj4tzmq',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://filepicker-images.genius.com/lal7cj4tzmq',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://filepicker-images.genius.com/d3r6dfclms',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 1435772,
#        'iq': 15791,
#        'login': 'SinaKeshavarz',
#        'name': 'SinaKeshavarz',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/SinaKeshavarz',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.2771822358346095,
#       'pinned_role': None,
#       'user': {'api_path': '/users/2523967',
#        'avatar': {'tiny': {'url': 'https://filepicker-images.genius.com/ly6acxmejsk',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://filepicker-images.genius.com/ly6acxmejsk',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://filepicker-images.genius.com/ly6acxmejsk',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://filepicker-images.genius.com/ly6acxmejsk',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://filepicker-images.genius.com/sc5vst9wxz',
#        'human_readable_role_for_display': 'Editor',
#        'id': 2523967,
#        'iq': 368922,
#        'login': 'heartlessswine',
#        'name': 'heartlessswine',
#        'role_for_display': 'editor',
#        'url': 'https://genius.com/heartlessswine',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.1791730474732006,
#       'pinned_role': None,
#       'user': {'api_path': '/users/1603328',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/773f9640b0b2e0ad1c6f7fedffb70a1d',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/773f9640b0b2e0ad1c6f7fedffb70a1d',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/773f9640b0b2e0ad1c6f7fedffb70a1d',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/773f9640b0b2e0ad1c6f7fedffb70a1d',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/e372f40ee0a6d090ffd11b4c5518a5a9.1000x370x1.jpg',
#        'human_readable_role_for_display': 'Moderator',
#        'id': 1603328,
#        'iq': 454437,
#        'login': 'kingkillmonger',
#        'name': 'ʞ|ace|woe|k',
#        'role_for_display': 'moderator',
#        'url': 'https://genius.com/kingkillmonger',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.06584992343032159,
#       'pinned_role': None,
#       'user': {'api_path': '/users/116340',
#        'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/4955c7795dbe34cdb329280940bf8639',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/4955c7795dbe34cdb329280940bf8639',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.rapgenius.com/avatars/small/4955c7795dbe34cdb329280940bf8639',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.rapgenius.com/avatars/medium/4955c7795dbe34cdb329280940bf8639',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.rapgenius.com/avatars/medium/4955c7795dbe34cdb329280940bf8639',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 116340,
#        'iq': 412715,
#        'login': 'palacelight',
#        'name': 'Reuben Tasker',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/palacelight',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.045941807044410414,
#       'pinned_role': None,
#       'user': {'api_path': '/users/11552371',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/190ae7c2aa75edfa6d058c43a139b996',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/190ae7c2aa75edfa6d058c43a139b996',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/190ae7c2aa75edfa6d058c43a139b996',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/190ae7c2aa75edfa6d058c43a139b996',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/62ea38d6b19880c1f2a9acb15fac2899.1000x188x1.png',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 11552371,
#        'iq': 74783,
#        'login': 'antypodean',
#        'name': 'antypodean',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/antypodean',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.02909647779479326,
#       'pinned_role': None,
#       'user': {'api_path': '/users/7',
#        'avatar': {'tiny': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/tiny/FPUgkjhRQyqsg9SfDfhx.jpg',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/thumb/FPUgkjhRQyqsg9SfDfhx.jpg',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/small/FPUgkjhRQyqsg9SfDfhx.jpg',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/FPUgkjhRQyqsg9SfDfhx.jpg',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/FPUgkjhRQyqsg9SfDfhx.jpg',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 7,
#        'iq': 561268,
#        'login': 'Maboo',
#        'name': 'Maboo',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/Maboo',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.016845329249617153,
#       'pinned_role': None,
#       'user': {'api_path': '/users/1940885',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/fb2fbf6aad634e3de4154c604dd6a29f',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/fb2fbf6aad634e3de4154c604dd6a29f',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/fb2fbf6aad634e3de4154c604dd6a29f',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/fb2fbf6aad634e3de4154c604dd6a29f',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/avatars/medium/fb2fbf6aad634e3de4154c604dd6a29f',
#        'human_readable_role_for_display': 'Editor',
#        'id': 1940885,
#        'iq': 31012,
#        'login': 'Light102',
#        'name': 'Light102',
#        'role_for_display': 'editor',
#        'url': 'https://genius.com/Light102',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.009188361408882083,
#       'pinned_role': None,
#       'user': {'api_path': '/users/3827128',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/5d3785ef75ad140bb873ff3268a04af4',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/5d3785ef75ad140bb873ff3268a04af4',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/5d3785ef75ad140bb873ff3268a04af4',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/5d3785ef75ad140bb873ff3268a04af4',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://filepicker-images.genius.com/Aa0OBQsSYGMULy66fdQQ_tumblr_static_tumblr_static_filename_640.png',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 3827128,
#        'iq': 1036,
#        'login': 'smigglesandgiggles',
#        'name': 'smigglesandgiggles',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/smigglesandgiggles',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.0061255742725880545,
#       'pinned_role': None,
#       'user': {'api_path': '/users/4467363',
#        'avatar': {'tiny': {'url': 'https://assets.genius.com/images/default_avatar_16.png?1759605527',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://assets.genius.com/images/default_avatar_32.png?1759605527',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://assets.genius.com/images/default_avatar_100.png?1759605527',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://assets.genius.com/images/default_avatar_300.png?1759605527',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1759605527',
#        'human_readable_role_for_display': 'Contributor',
#        'id': 4467363,
#        'iq': 4104,
#        'login': 'gone_2nr1f_1573',
#        'name': 'gone_2nr1f_1573',
#        'role_for_display': 'contributor',
#        'url': 'https://genius.com/gone_2nr1f_1573',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.0030627871362940273,
#       'pinned_role': None,
#       'user': {'api_path': '/users/265732',
#        'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/c9afb3ba2c2704fa76ff242f1eadcd03',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/c9afb3ba2c2704fa76ff242f1eadcd03',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.rapgenius.com/avatars/small/c9afb3ba2c2704fa76ff242f1eadcd03',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.rapgenius.com/avatars/medium/c9afb3ba2c2704fa76ff242f1eadcd03',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.rapgenius.com/avatars/medium/c9afb3ba2c2704fa76ff242f1eadcd03',
#        'human_readable_role_for_display': 'Editor',
#        'id': 265732,
#        'iq': 260664,
#        'login': 'Vesuvius',
#        'name': 'Vesuvius',
#        'role_for_display': 'editor',
#        'url': 'https://genius.com/Vesuvius',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.0015313935681470136,
#       'pinned_role': None,
#       'user': {'api_path': '/users/1793633',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/402f982c45c1335b41012bd7b096eac5',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/402f982c45c1335b41012bd7b096eac5',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/402f982c45c1335b41012bd7b096eac5',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/402f982c45c1335b41012bd7b096eac5',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/avatars/medium/402f982c45c1335b41012bd7b096eac5',
#        'human_readable_role_for_display': 'Editor',
#        'id': 1793633,
#        'iq': 141045,
#        'login': 'Nettacki',
#        'name': 'Nettacki',
#        'role_for_display': 'editor',
#        'url': 'https://genius.com/Nettacki',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}},
#      {'attribution': 0.0015313935681470136,
#       'pinned_role': None,
#       'user': {'api_path': '/users/19665664',
#        'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/2e5b0323a9f93eee90e1cf9533e44588',
#          'bounding_box': {'width': 16, 'height': 16}},
#         'thumb': {'url': 'https://images.genius.com/avatars/thumb/2e5b0323a9f93eee90e1cf9533e44588',
#          'bounding_box': {'width': 32, 'height': 32}},
#         'small': {'url': 'https://images.genius.com/avatars/small/2e5b0323a9f93eee90e1cf9533e44588',
#          'bounding_box': {'width': 100, 'height': 100}},
#         'medium': {'url': 'https://images.genius.com/avatars/medium/2e5b0323a9f93eee90e1cf9533e44588',
#          'bounding_box': {'width': 300, 'height': 400}}},
#        'header_image_url': 'https://images.genius.com/avatars/medium/2e5b0323a9f93eee90e1cf9533e44588',
#        'human_readable_role_for_display': None,
#        'id': 19665664,
#        'iq': 120,
#        'login': 'LogCabin',
#        'name': 'LogCabin',
#        'role_for_display': None,
#        'url': 'https://genius.com/LogCabin',
#        'current_user_metadata': {'permissions': ['follow'],
#         'excluded_permissions': [],
#         'interactions': {'following': False}}}}],
#     'cosigned_by': [],
#     'rejection_comment': None,
#     'verified_by': None}]},
#  'user': None}

# %% [markdown]
# ## Exercise 3
#
# Use the result from Exercise 2 to create another method for our `Genius` class called `.get_artists(search_terms)` (plural) which takes in a *list* of search terms, and returns a DataFrame containing a row for each search term, and the following columns:
#
# - `search_term`: the raw search term from `search_terms`
# - `artist_name`: the (most likely) artist name for the search term
# - `artist_id`: the Genius Artist ID for that artist, based on the API call
# - `followers_count`: the number of followers for that artist (if available)
#
# For example, the following should return a DataFrame with 4 rows:
#
# ```python
# genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# ```

# %%
# Ex3
df = genius.get_artists(["Rihanna", "Tycho", "Seal", "U2"])
df
# Out:
#   search_term   artist_name  artist_id  followers_count
# 0     Rihanna       Rihanna         89             5800
# 1       Tycho         Tycho      53336               30
# 2        Seal  Lil Uzi Vert     217208             6165
# 3          U2            U2      23895              374

# %% [markdown]
# ## Bonus Exercise (optional)
#
# 1. Gather a list of 100+ various musical artists, and save this list in a TXT file.
# 2. Write a Python *script* that saves the result of `.get_artists` for these artists in a CSV file.
# 3. If you have time, adjust this script to use multiprocessing.

# %%
import os
import time
import pandas as pd
from pathlib import Path
